# %%
import pandas as pd
import numpy as np
import seaborn as sns
import glob
from matplotlib import pyplot as plt
import matplotlib.patches as patches
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from numpy.fft import fft, ifft
import math 
import scipy.signal
import xgboost as xgb
from xgboost import plot_importance, plot_tree
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import GridSearchCV
from sklearn.decomposition import PCA
sns.set()

# %%
DF_asset=pd.read_csv("assets.csv")
DF_asset['sensors'] = DF_asset['sensors'].str[2:9]
DF_asset_clean = DF_asset[['sensors', 'modelType',
       'name', 'specifications.axisX', 'specifications.axisY',
       'specifications.axisZ', 'specifications.maxDowntime',
       'specifications.maxTemp', 'specifications.power', 'specifications.rpm',
       'specifications.workdays']].copy()
DF_asset_clean.columns = DF_asset_clean.columns.str.replace('specifications.', '')

DF_collects=pd.read_csv("collects.csv")
DF_collects_clean = DF_collects[['sensorId','params.accelRMS.x', 'params.accelRMS.y',
       'params.accelRMS.z', 'params.duration', 'params.sampRate',
       'params.timeStart', 'params.velRMS.x', 'params.velRMS.y',
       'params.velRMS.z', 'temp']].copy()
DF_collects_clean.columns = DF_collects_clean.columns.str.replace('params.', '')
array_main = []
for i in DF_collects_clean["sensorId"].unique():
    size = DF_collects_clean[DF_collects_clean["sensorId"]==i].shape[0]
    sample = DF_collects_clean.loc[DF_collects_clean["sensorId"]==i,"duration"].iloc[0]
    array_aux = np.linspace(0,int(size*sample),size)
    array_main = np.append(array_main,array_aux)
DF_collects_clean["time"] = array_main

DF_merge = DF_collects_clean.merge(DF_asset_clean, left_on='sensorId', right_on='sensors')
# Out:
# C:\Users\Leonardo\AppData\Local\Temp\ipykernel_12704\1828910478.py:8: FutureWarning: The default value of regex will change from True to False in a future version.
#   DF_asset_clean.columns = DF_asset_clean.columns.str.replace('specifications.', '')
# C:\Users\Leonardo\AppData\Local\Temp\ipykernel_12704\1828910478.py:15: FutureWarning: The default value of regex will change from True to False in a future version.
#   DF_collects_clean.columns = DF_collects_clean.columns.str.replace('params.', '')

# %%
DF_asset_clean
# Out:
#    sensors      modelType                                               name  \
# 0  IAJ9206     compressor  Ventilador Acima do Elemento GA160 FF - Prédio...
# 1  LZY4270  heaterFurnace                                           RDF-61.1
# 2  MUR8453    transformer                          TRANSFORMADOR 500 KVA N°1
# 3  MXK6435           pump      Motor Bomba - Tanque de Expansão Tubo Verde
# 4  MYD8706           pump                               CAG1- BAGS.12- Motor
# 5  MYS2071  heaterFurnace                                           VTF-61.1
# 6  MZU6388   eletricMotor                       Boko MA-1510 - Motor 2 da UH
# 7  NAH4736     compressor                  Ventilador -GA75 FF - Prédio B104
# 8  NAI1549           pump                               CAG1- BAGS.3- Motor
# 9  NEW4797          other                                  ROTULADORA SIDEL
#
#         axisX       axisY       axisZ  maxDowntime  maxTemp  power     rpm  \
# 0    vertical  horizontal       axial        48.00      NaN    3.7  1735.0
# 1       axial    vertical  horizontal         0.25     55.0    0.0  1740.0
# 2  horizontal    vertical         NaN          NaN     65.0    NaN     NaN
# 3  horizontal       axial    vertical        48.00      NaN    7.0  3525.0
# 4  horizontal       axial    vertical          NaN      NaN   30.0  1765.0
# 5       axial      radial  horizontal         0.25     60.0    1.5   894.0
# 6  horizontal    vertical      radial          NaN     65.0   37.0  1750.0
# 7         NaN         NaN         NaN        48.00      NaN    2.0  1080.0
# 8       axial  horizontal    vertical          NaN      NaN   75.0  1775.0
# 9         NaN         NaN         NaN         1.00     70.0    NaN  1458.0
#
#         workdays
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# 5             []
# 6  [0,1,2,3,4,5]
# 7            NaN
# 8            NaN
# 9            NaN

# %%
sns.set_style(style='white')

# %% [markdown]
# ## QUESTION 1

# %% [markdown]
# ## plots from asset.csv

# %%
# plot from asset
ax=sns.countplot(data=DF_asset_clean,x="modelType")
ax.set_xticklabels(ax.get_xticklabels(),rotation=30)
ax.set_title("Number of assets by modeltype")
# Out:
# Text(0.5, 1.0, 'Number of assets by modeltype')

# %%
# plot from asset
ax=sns.countplot(data=DF_asset_clean,x="axisX",hue="modelType")
ax.set_xticklabels(ax.get_xticklabels(),rotation=30)
ax.legend(loc='center left', bbox_to_anchor=(1.05, 0.5),
          ncol=1, fancybox=True, shadow=True)
ax.set_title("Axis X orientation by model type")
# Out:
# Text(0.5, 1.0, 'Axis X orientation by model type')

# %%
# plot from asset
ax=sns.countplot(data=DF_asset_clean,x="axisY",hue="modelType")
ax.set_xticklabels(ax.get_xticklabels(),rotation=30)
ax.legend(loc='center left', bbox_to_anchor=(1.05, 0.5),
          ncol=1, fancybox=True, shadow=True)
ax.set_title("Axis Y orientation by model type")
# Out:
# Text(0.5, 1.0, 'Axis Y orientation by model type')

# %%
# plot from asset
ax=sns.countplot(data=DF_asset_clean,x="axisZ",hue="modelType")
ax.set_xticklabels(ax.get_xticklabels(),rotation=30)
ax.legend(loc='center left', bbox_to_anchor=(1.05, 0.5),
          ncol=1, fancybox=True, shadow=True)
ax.set_title("Axis Z orientation by model type")
# Out:
# Text(0.5, 1.0, 'Axis Z orientation by model type')

# %%
ax=sns.scatterplot(data=DF_asset_clean[~DF_asset_clean["maxTemp"].isna()],x="modelType",y="maxTemp",hue="sensors")
ax.set_xticklabels(ax.get_xticklabels(),rotation=30)
ax.legend(loc='center left', bbox_to_anchor=(1.05, 0.5),
          ncol=1, fancybox=True, shadow=True)
ax.set_title("Maximum temperature allowed by asset")
# Out:
# C:\Users\Leonardo\AppData\Local\Temp\ipykernel_12704\3273015554.py:2: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(),rotation=30)
# Text(0.5, 1.0, 'Maximum temperature allowed by asset')

# %%
ax=sns.scatterplot(data=DF_asset_clean[~DF_asset_clean["power"].isna()],x="modelType",y="power",hue="sensors")
ax.set_xticklabels(ax.get_xticklabels(),rotation=30)
ax.legend(loc='center left', bbox_to_anchor=(1.05, 0.5),
          ncol=1, fancybox=True, shadow=True)
ax.set_title("Equipment horsepower")
# Out:
# C:\Users\Leonardo\AppData\Local\Temp\ipykernel_12704\4135667100.py:2: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(),rotation=30)
# Text(0.5, 1.0, 'Equipment horsepower')

# %%
ax=sns.scatterplot(data=DF_asset_clean[~DF_asset_clean["rpm"].isna()],x="modelType",y="rpm",hue="sensors")
ax.set_xticklabels(ax.get_xticklabels(),rotation=30)
ax.legend(loc='center left', bbox_to_anchor=(1.05, 0.5),
          ncol=1, fancybox=True, shadow=True)
ax.set_title("Nominal RPM value")
# Out:
# C:\Users\Leonardo\AppData\Local\Temp\ipykernel_12704\749691954.py:2: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(),rotation=30)
# Text(0.5, 1.0, 'Nominal RPM value')

# %%
ax=sns.scatterplot(data=DF_asset_clean[~DF_asset_clean["maxDowntime"].isna()],x="modelType",y="maxDowntime",hue="sensors")
ax.set_xticklabels(ax.get_xticklabels(),rotation=30)
ax.legend(loc='center left', bbox_to_anchor=(1.05, 0.5),
          ncol=1, fancybox=True, shadow=True)
# Out:
# C:\Users\Leonardo\AppData\Local\Temp\ipykernel_12704\795918322.py:2: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(),rotation=30)

# %%
DF_collects_clean["sensorId"].unique()
# Out:
# array(['IAJ9206', 'LZY4270', 'MUR8453', 'MXK6435', 'MYD8706', 'MYS2071',
#        'MZU6388', 'NAH4736', 'NAI1549', 'NEW4797'], dtype=object)

# %% [markdown]
# ## plots from collects file for a single sensor

# %%
sensor = "MUR8453"
plt.figure(figsize=(12, 6))
ax = sns.lineplot(data=DF_collects_clean[DF_collects_clean["sensorId"]==sensor],x="time",y="temp")
#ax.axhline(y=int(DF_asset_clean.loc[DF_asset_clean["sensors"]==sensor,"maxTemp"]), linewidth=2, color='orange', ls=':')
ax.set_title(sensor + " Temperature")
# Out:
# Text(0.5, 1.0, 'MUR8453 Temperature')

# %%
plt.figure(figsize=(12, 6))
ax =sns.lineplot(data=DF_collects_clean[DF_collects_clean["sensorId"]==sensor],x="time",y="velRMS.x")
ax.set_title(sensor + " Velocity in x")
#ax.axhline(y=0.0003, linewidth=2, color='orange', ls=':')
# Out:
# Text(0.5, 1.0, 'MUR8453 Velocity in x')

# %%
plt.figure(figsize=(12, 6))
ax=sns.lineplot(data=DF_collects_clean[DF_collects_clean["sensorId"]==sensor],x="time",y="velRMS.y")
ax.set_title(sensor + " Velocity in y")
#ax.axhline(y=0.0003, linewidth=2, color='orange', ls=':')
# Out:
# Text(0.5, 1.0, 'MUR8453 Velocity in y')

# %%
plt.figure(figsize=(12, 6))
ax=sns.lineplot(data=DF_collects_clean[DF_collects_clean["sensorId"]==sensor],x="time",y="velRMS.z")
ax.set_title(sensor + " Velocity in z")
#ax.axhline(y=0.00025, linewidth=2, color='orange', ls=':')
# Out:
# Text(0.5, 1.0, 'MUR8453 Velocity in z')

# %%
plt.figure(figsize=(12, 6))
ax=sns.lineplot(data=DF_collects_clean[DF_collects_clean["sensorId"]==sensor],x="time",y="accelRMS.x")
ax.set_title(sensor + " Acceleration in x")
# Out:
# Text(0.5, 1.0, 'MUR8453 Acceleration in x')

# %%
plt.figure(figsize=(12, 6))
ax=sns.lineplot(data=DF_collects_clean[DF_collects_clean["sensorId"]==sensor],x="time",y="accelRMS.y")
ax.set_title(sensor + " Acceleration in y")
# Out:
# Text(0.5, 1.0, 'MUR8453 Acceleration in y')

# %%
plt.figure(figsize=(12, 6))
ax=sns.lineplot(data=DF_collects_clean[DF_collects_clean["sensorId"]==sensor],x="time",y="accelRMS.z")
ax.set_title(sensor + " Acceleration in x")
# Out:
# Text(0.5, 1.0, 'MUR8453 Acceleration in x')

# %% [markdown]
# ##  QUESTION 2

# %%
## 2 Downtime and uptime
# idea -> using the vibration data from all three axis whenever the accelaration is ~0  in all three axis 
# we consider that the machine is down. Summing the "duration" of each period of time when the machine is down, we will 
# be able to acquire the total downtime, and by consequence the uptime too.

# For this question I will use the asset "IAJ9206"

# %%
DF_Q2 = DF_collects_clean.loc[DF_collects_clean["sensorId"]=="IAJ9206"].copy()

# %%
# the function here solely compare all three velocity value for each coordanate, if all three are below a threshold,
# we consider that the machine is down 
# i created the function with this structure instead of directly analysing the dataframe at once because this makes more sense
# due to the fact that we do not have all the information at once, we need to analyse step-by-step

def downtime_q(x,y,z,trh=0.0003,duration=3.006):
    if (x < trh) & (y < trh) & (z < trh):
        time = duration
    else:
        time = 0
    return time

# %%
# mockup data acquisition in time
downtime=0
total_time =0
for i in range(DF_Q2.shape[0]):
    x=DF_Q2["velRMS.x"].iloc[i]
    y=DF_Q2["velRMS.y"].iloc[i]
    z=DF_Q2["velRMS.z"].iloc[i]
    time=downtime_q(x,y,z,trh=0.0002,duration=3.006)
    downtime = downtime + time
    total_time = total_time + 3.006

print("Downtime " + str(downtime) + " seconds")
print("Uptime " + str(total_time-downtime) + " seconds")
if downtime/60 < 48:
    print("Downtime below maximum downtime allowed!")
else: 
    print("Downtime above maximum downtime allowed!!!!!!!!!!")
# Out:
# Downtime 1764.5220000000138 seconds
# Uptime 10217.393999999586 seconds
# Downtime below maximum downtime allowed!

# %% [markdown]
# ## QUESTION 3

# %%
# For this task a possible way to analyzing the vibration signals is to "cut the signal" into observation windows
# and apply fft and compare the harmonic components for each observation window, and whenever there is a "relevant"
# difference we will consider that there is a change in the system behavior.
# this type of analysis can help us understand the different type loads that the system is subject

# %%
DF_Q3 = DF_collects_clean.loc[DF_collects_clean["sensorId"]=="MZU6388"].copy()
#removing a single NaN measurement.
DF_Q3.dropna(inplace=True)
DF_Q3["obs_win"]=pd.qcut(DF_Q3["time"], 20,labels=False)
a,ret=pd.qcut(DF_Q3["time"],20, labels=False,retbins=True)

# %%
## creating the functions
## FUNCTION TO OBTAIN THE WINDOW VALUE
def var_on_obs_win(x,x_win,obs_win_size,duration):
    x_win = np.append(x_win,x)
    if len(x_win) == obs_win_size:
        sr = DF_Q3["sampRate"].iloc[0]
        sos = scipy.signal.butter(5, 0.5, 'highpass', fs=sr, output='sos')
        x_filtered = scipy.signal.sosfiltfilt(sos, x_win)
        X_filtered = fft(x_filtered)
        X_filtered_abs = np.abs(X_filtered)
        X_filtered_abs_mean = np.mean(X_filtered_abs)
        X_filtered_abs_std = np.std(X_filtered_abs)
        valu_on_window = X_filtered_abs_mean + X_filtered_abs_std
        x_win=[]
    else:
        valu_on_window = 0
    return x_win, valu_on_window

## FUNCTION TO COMPARE THE WINDOWS
def compa_win(valu_all,valu_on_window,thre,obs_win_size,duration):
    if len(valu_all) == 0:
        compa= 0
        valu_all = np.append(valu_all,valu_on_window)
    else:
        compa_1 = np.abs(valu_on_window-valu_all[-1])/valu_all[-1]
        compa_2 = np.abs(valu_on_window-valu_all[-1])/valu_on_window
        zscore_valu_ow = (valu_on_window - np.mean(valu_all)) / np.std(valu_all)
        print(str(zscore_valu_ow))
        valu_all = np.append(valu_all,valu_on_window)
        if (zscore_valu_ow >= 2): #| (compa_2 >= thre):
            print("!!!!!!!the system load changed!!!!!!!!!" +"observation window " + str(len(valu_all)+1) + " starting at " + str(obs_win_size*duration*(len(valu_all)-1)))
        else:
            print("the system load is the same")
    return valu_all

# %%
# mockup data acquisition in time
x_win = []
valu_all = []
for i in range(0,len(DF_Q3["accelRMS.x"]),1):
    x=DF_Q3["accelRMS.x"].iloc[i]
    x_win, valu_on_window=var_on_obs_win(x,x_win,140,4.003)
    if valu_on_window != 0:
        print(str(i)+" "+str(valu_on_window.round(6))+"!!!!!!!!!!!!!!!!!!!!!!!!")
        valu_all=compa_win(valu_all,valu_on_window,1.5,140,4.003)
# Out:
# 139 0.001678!!!!!!!!!!!!!!!!!!!!!!!!
# 279 0.001244!!!!!!!!!!!!!!!!!!!!!!!!
# -inf
# the system load is the same
# 419 0.001481!!!!!!!!!!!!!!!!!!!!!!!!
# 0.0931823053607325
# the system load is the same
# 559 0.00367!!!!!!!!!!!!!!!!!!!!!!!!
# 12.393906606426711
# !!!!!!!the system load changed!!!!!!!!!observation window 5 starting at 1681.2600000000002
# 699 0.002075!!!!!!!!!!!!!!!!!!!!!!!!
# 0.05879613881155661
# the system load is the same
# 839 0.001114!!!!!!!!!!!!!!!!!!!!!!!!
# -1.0596274151095497
# the system load is the same
# 979 0.001085!!!!!!!!!!!!!!!!!!!!!!!!
# -0.921770832438256
# the system load is the same
# 1119 0.00158!!!!!!!!!!!!!!!!!!!!!!!!
# -0.21804596120803665
# the system load is the same
# 1259 0.001805!!!!!!!!!!!!!!!!!!!!!!!!
# 0.08088113761448046
# the system load is the same
# 1399 0.004185!!!!!!!!!!!!!!!!!!!!!!!!
# 3.269180727037607
# !!!!!!!the system load changed!!!!!!!!!observation window 11 starting at 5043.780000000001
# 1539 0.002261!!!!!!!!!!!!!!!!!!!!!!!!
# 0.26435992884695875
# the system load is the same
# 1679 0.004049!!!!!!!!!!!!!!!!!!!!!!!!
# 2.0894002733706714
# !!!!!!!the system load changed!!!!!!!!!observation window 13 starting at 6164.620000000001
# 1819 0.291069!!!!!!!!!!!!!!!!!!!!!!!!
# 265.5308289810515
# !!!!!!!the system load changed!!!!!!!!!observation window 14 starting at 6725.040000000001
# 1959 0.001311!!!!!!!!!!!!!!!!!!!!!!!!
# -0.3000078604071492
# the system load is the same
# 2099 0.485751!!!!!!!!!!!!!!!!!!!!!!!!
# 6.221064674689526
# !!!!!!!the system load changed!!!!!!!!!observation window 16 starting at 7845.880000000001
# 2239 0.550047!!!!!!!!!!!!!!!!!!!!!!!!
# 3.6490166038079646
# !!!!!!!the system load changed!!!!!!!!!observation window 17 starting at 8406.300000000001
# 2379 0.261842!!!!!!!!!!!!!!!!!!!!!!!!
# 0.9937879874938977
# the system load is the same
# 2519 0.442539!!!!!!!!!!!!!!!!!!!!!!!!
# 1.9528290705830078
# the system load is the same
# 2659 0.569544!!!!!!!!!!!!!!!!!!!!!!!!
# 2.391161991443197
# !!!!!!!the system load changed!!!!!!!!!observation window 20 starting at 10087.560000000001
# C:\Users\Leonardo\AppData\Local\Temp\ipykernel_12704\1483634768.py:27: RuntimeWarning: divide by zero encountered in scalar divide
#   zscore_valu_ow = (valu_on_window - np.mean(valu_all)) / np.std(valu_all)

# %%
event = [1681,5043,6164,6725,7845,8406,10087]

# %%
my_labels = {"x1" : "events", "x2" : "observation windows"}
ax=sns.lineplot(data=DF_collects_clean[DF_collects_clean["sensorId"]=="MZU6388"],x="time",y="accelRMS.x",label='accelRMS in x')
ax.set_title(sensor + " accelRMS in x")
#event = [6725,7285,7845]
for j in range(0,len(event),1):
    ax.axvline(x=event[j], linewidth=1.5, color='red', ls=':',label=my_labels["x1"])
    my_labels["x1"] = "_nolegend_"
for  i in range(1,len(ret),1):   
    ax.axvline(x=ret[i], linewidth=0.5, color='green', ls=':',label=my_labels["x2"])  
    my_labels["x2"] = "_nolegend_"
ax.legend(loc='center left', bbox_to_anchor=(1.05, 0.5),
          ncol=1, fancybox=True, shadow=True)

# %%
# PLOTS FOR CURIOSITY SAKE

# %%
g = sns.jointplot(x="accelRMS.x", y="temp", data=DF_Q3, kind="kde")
g.plot_joint(plt.scatter, c="c", s=30, linewidth=1, marker="+")
g.ax_joint.collections[0].set_alpha(0)
plt.xlim([-0.02, 0.15])
plt.ylim([0, 60])
g.set_axis_labels("accelRMS.x", "temp")

# %% [markdown]
# ## QUESTION 4

# %%
# I will use xgboost to do a time series forecasting, then calculate the residue signal x - xhat, after that use 
# an evaluation function and compare the acquired signal with some criteria to consider if this a fault 
# or a regular change of load
# besides the forecasting, some parameter do not need this intricate solution, such as temperature and rpm, if those 
# parameters surpasses an predeterminated threshold we will consider that is a fault.
# and the third situation that sshould be accounted for is the sensor fault which is caracterized by NaN value of the measurement

# %%
DF_collects_clean.columns
# Out:
# Index(['sensorId', 'accelRMS.x', 'accelRMS.y', 'accelRMS.z', 'duration',
#        'sampRate', 'timeStart', 'velRMS.x', 'velRMS.y', 'velRMS.z', 'temp',
#        'time'],
#       dtype='object')

# %%
sensor="NEW4797"

# %%
plt.figure(figsize=(12, 6))
ax=sns.lineplot(data=DF_collects_clean[DF_collects_clean["sensorId"]==sensor],x="time",y="accelRMS.z")
ax.set_title(sensor + " Acceleration in z")
# Out:
# Text(0.5, 1.0, 'NEW4797 Acceleration in z')

# %%
plt.figure(figsize=(12, 6))
ax=sns.lineplot(data=DF_collects_clean[DF_collects_clean["sensorId"]==sensor],x="time",y="temp")
ax.set_title(sensor + " temp")
# Out:
# Text(0.5, 1.0, 'NEW4797 temp')

# %%
#USING THE SENSOR MYD8706
DF_Q4 = DF_collects_clean[DF_collects_clean["sensorId"]==sensor].copy()
#getting only the necessary features
DF_Q4_slim = DF_Q4[["accelRMS.z", "temp", "time"]].copy()

# %%
# Separeting the data into train test ad validation
DF_Q4_slim_train = DF_Q4_slim.loc[DF_Q4_slim["time"] <= 1500].copy()
DF_Q4_slim_test = DF_Q4_slim.loc[(DF_Q4_slim["time"] > 1500)&(DF_Q4_slim["time"] <= 3000)].copy()
DF_Q4_slim_validation = DF_Q4_slim.loc[DF_Q4_slim["time"]> 3000].copy()

# %%
# Separating the data into input and output
y_train = DF_Q4_slim_train["accelRMS.z"].copy()
X_train = DF_Q4_slim_train[["temp","time"]].copy()

y_test = DF_Q4_slim_test["accelRMS.z"].copy()
X_test = DF_Q4_slim_test[["temp","time"]].copy()

y_validation = DF_Q4_slim_validation["accelRMS.z"].copy()
X_validation = DF_Q4_slim_validation[["temp","time"]].copy()

# %%
def hyperParameterTuning(X_train, y_train):
    param_tuning = {
        'learning_rate': [0.01, 0.1, 0.2, 0.4, 0.7],
        'max_depth': [3, 5, 7, 10],
        'min_child_weight': [1, 3, 5],
        'subsample': [0.5, 0.7],
        'colsample_bytree': [0.5, 0.7],
        'n_estimators' : [100, 200, 500],
        'objective': ['reg:squarederror','reg:squaredlogerror','reg:absoluteerror']
    }

    xgb_model = xgb.XGBRegressor()

    gsearch = GridSearchCV(estimator = xgb_model,
                           param_grid = param_tuning,                        
                           cv = 5,
                           n_jobs = -1,
                           verbose = 1)

    gsearch.fit(X_train,y_train)
    return gsearch.best_params_

# %%
hyperParameterTuning(X_train, y_train)
# Out:
# Fitting 5 folds for each of 2160 candidates, totalling 10800 fits
# {'colsample_bytree': 0.5,
#  'learning_rate': 0.01,
#  'max_depth': 3,
#  'min_child_weight': 3,
#  'n_estimators': 500,
#  'objective': 'reg:squaredlogerror',
#  'subsample': 0.5}

# %%
xgb_model = xgb.XGBRegressor(
        objective = 'reg:absoluteerror',
        colsample_bytree = 0.5,
        learning_rate = 0.4,
        max_depth = 9,
        min_child_weight = 5,
        n_estimators = 500,
        subsample = 0.5)

# %time xgb_model.fit(X_train, y_train, early_stopping_rounds=5, eval_set=[(X_test, y_test)], verbose=False)

y_pred_xgb = xgb_model.predict(X_test)

mae_xgb = mean_absolute_error(y_test, y_pred_xgb)
mse_xgb = mean_squared_error(y_test, y_pred_xgb)
print("MAE: ", mae_xgb)
print("MSE: ", mse_xgb)
# Out:
# CPU times: total: 156 ms
# Wall time: 20.9 ms
# MAE:  0.03118799105901938
# MSE:  0.0014472924778285825
# C:\ProgramData\anaconda3\Lib\site-packages\xgboost\sklearn.py:889: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(

# %%
# validating the model with a naive data
y_validation_xgb = xgb_model.predict(X_validation)

# %%
#ploting the real validation values and the values acquired with xgboost
fig=plt.figure(figsize=(12, 6))
ax = plt.axes()
ax.set_facecolor("white")
ax.spines['bottom'].set_color('black')
ax.spines['top'].set_color('black') 
ax.spines['right'].set_color('black')
ax.spines['left'].set_color('black')
plt.plot(X_validation["time"], y_validation_xgb, label = "XGB",linestyle='-') 
plt.plot(X_validation["time"], y_validation, label = "Real",linestyle=':') 
plt.legend() 
plt.show()

# %%
resi =  y_validation -y_validation_xgb

# %%
# residuel value plot
plt.figure(figsize=(12, 6))
ax = plt.axes()
ax.set_facecolor("white")
ax.spines['bottom'].set_color('black')
ax.spines['top'].set_color('black') 
ax.spines['right'].set_color('black')
ax.spines['left'].set_color('black')
plt.plot(X_validation["time"], resi, label = "Residue",linestyle='-') 
plt.legend() 
plt.show()

# %%
def fault_detection(xgb_model,thre,input_data,temp_thre,resi_count,sen_fault):
    if input_data["temp"][0]>= temp_thre:
        print("!!!!!!!Fault Detected the equipment is overheating!!!!!!!!")
    if math.isnan(input_data["accelRMS.z"]):
        sen_fault += 1
        if sen_fault > 20:
            print("!!!!!!!The sensor is not working properly!!!!!!!!")
    yhat = xgb_model.predict(input_data[["temp","time"]])
    resi = float(input_data["accelRMS.z"]-yhat)
    print(str(resi))
    if resi >=thre:
        resi_count += 1
        if resi_count > 5:
            print("!!!!!!!The equipment needs attention, fault might occur !!!!!!!!")
    return resi_count,sen_fault,resi

# %%
# mockup data acquisition in time
resi_count = 0
sen_fault = 0
resi_plot =[]
for i in range(0,DF_Q4_slim_validation.shape[0],1):
    print(i)
    d = {'accelRMS.z': [DF_Q4_slim_validation.iloc[i][0]]
     , 'temp': [DF_Q4_slim_validation.iloc[i][1]]
     , 'time': [DF_Q4_slim_validation.iloc[i][2]]}
    dataframe_nano = pd.DataFrame(data=d)
    resi_count,sen_fault,resi_aux=fault_detection(xgb_model,0.15,dataframe_nano,70.0,resi_count,sen_fault)
    resi_plot = np.append(resi_plot,resi_aux)
# Out:
# 0
# 0.06681488084864616
# 1
# 0.06709027931094169
# 2
# 0.06960212005352974
# 3
# 0.06284952114582061
# 4
# 0.04315732041144371
# 5
# 0.07396228003895283
# 6
# 0.050622122963190075
# 7
# 0.044289320411443706
# 8
# 0.02640168018817901
# 9
# 0.04103532041144371
# 10
# 0.06277352010321617
# 11
# 0.04203032041144371
# 12
# -0.02251235899066925
# 13
# -0.012825119151353835
# 14
# -0.011020119151353838
# 15
# -0.005027959208607675
# 16
# 0.052546320411443706
# 17
# 0.06742372194933892
# 18
# -0.05087031981182098
# 19
# 0.037277242516040796
# 20
# 0.021765075314998633
# 21
# 0.02981347846221924
# 22
# -0.01847112216758728
# 23
# 0.07168472194933892
# 24
# 0.0568912425160408
# 25
# 0.031229075314998633
# 26
# 0.05066887791728973
# 27
# 0.023752075314998622
# 28
# -0.020218957100868226
# 29
# -0.01673495858836174
# 30
# -0.01628447989678383
# 31
# 0.04059124251604081
# 32
# 0.043405242516040804
# 33
# 0.039973439816474915
# 34
# -0.03264548202037811
# 35
# 0.03866443981647491
# 36
# 0.0465202425160408
# 37
# 0.048860242516040805
# 38
# 0.0361872425160408
# 39
# 0.0373662425160408
# 40
# 0.06769572194933891
# 41
# 0.05652043981647492
# 42
# 0.05484343981647491
# 43
# 0.04213543981647491
# 44
# -0.03615767958855629
# 45
# -0.01954147885417938
# 46
# -0.04652267958855629
# 47
# -0.04764348202037811
# 48
# -0.051396761437892916
# 49
# -0.05631843887853622
# 50
# -0.027757920500040056
# 51
# -0.02871971809720993
# 52
# -0.02841972125172615
# 53
# -0.012745120579123498
# 54
# -0.013224519714355468
# 55
# -0.018051119552135467
# 56
# -0.017870119552135466
# 57
# -0.01790111955213547
# 58
# -0.01790711955213547
# 59
# -0.01799111955213547
# 60
# -0.01421824041736126
# 61
# -0.01421424041736126
# 62
# -0.01411024041736126
# 63
# -0.006666840070605278
# 64
# -0.006610840070605278
# 65
# -0.006584840070605278
# 66
# -0.006839840070605278
# 67
# -0.006635840070605278
# 68
# -0.006732840070605278
# 69
# -0.006672840070605278
# 70
# -0.006791840070605278
# 71
# -0.006693840070605278
# 72
# -0.006580840070605278
# 73
# -0.006704840070605278
# 74
# -0.006788840070605278
# 75
# -0.006708840070605278
# 76
# -0.006699840070605278
# 77
# -0.006614840070605278
# 78
# -0.006651840070605278
# 79
# -0.006588840070605278
# 80
# -0.006683840070605278
# 81
# -0.006556840070605278
# 82
# -0.006636840070605278
# 83
# -0.006934840070605278
# 84
# -0.006734840070605278
# 85
# -0.006796840070605278
# 86
# -0.006824840070605278
# 87
# -0.006678840070605278
# 88
# -0.0065658400706052784
# 89
# -0.006661840070605278
# 90
# -0.006681840070605278
# 91
# -0.006666840070605278
# 92
# -0.006837840070605278
# 93
# -0.006709840070605278
# 94
# -0.006695840070605278
# 95
# -0.006686840070605278
# 96
# -0.006451840070605278
# 97
# -0.006723840070605278
# 98
# -0.006770840070605278
# 99
# -0.006686840070605278
# 100
# -0.006700840070605278
# 101
# -0.006856840070605278
# 102
# -0.006744840070605278
# 103
# -0.006644840070605278
# 104
# -0.006672840070605278
# 105
# -0.006685840070605278
# 106
# -0.006548840070605278
# 107
# -0.006538840070605278
# 108
# -0.006905840070605278
# 109
# -0.006692840070605278
# 110
# -0.006817840070605278
# 111
# -0.006680840070605278
# 112
# -0.006821840070605278
# 113
# -0.006753840070605278
# 114
# -0.006629840070605278
# 115
# -0.006593840070605278
# 116
# -0.006826840070605278
# 117
# -0.006683840070605278
# 118
# -0.006666840070605278
# 119
# -0.006559840070605278
# 120
# -0.006723840070605278
# 121
# -0.006731840070605278
# 122
# -0.006636840070605278
# 123
# -0.006560840070605278
# 124
# -0.006767840070605278
# 125
# -0.006451840070605278
# 126
# -0.006654840070605278
# 127
# 0.002037159929394723
# 128
# -0.006413840070605278
# 129
# -0.006574840070605278
# 130
# -0.006700840070605278
# 131
# -0.006637840070605278
# 132
# -0.006669840070605278
# 133
# -0.006555840070605278
# 134
# -0.006705840070605278
# 135
# 0.002539159929394722
# 136
# 0.003025159929394722
# 137
# 0.002232159929394722
# 138
# -0.006683840070605278
# 139
# -0.006636840070605278
# 140
# -0.006801840070605278
# 141
# -0.006728840070605278
# 142
# -0.006586840070605278
# 143
# 0.0024321599293947224
# 144
# -0.006654840070605278
# 145
# -0.006765840070605278
# 146
# 0.000848159929394722
# 147
# -0.006483840070605278
# 148
# 0.0045551599293947205
# 149
# -0.013799119552135468
# 150
# 0.0005738794208765031
# 151
# -0.031510560183525084
# 152
# -0.02689228071641922
# 153
# -0.03163067958855629
# 154
# -0.033097678035974507
# 155
# -0.01938835899066925
# 156
# -0.044499362603187556
# 157
# -0.013857119151353837
# 158
# -0.011272119151353836
# 159
# -0.0012057206890583039
# 160
# -0.003527720689058305
# 161
# -0.002174720689058305
# 162
# -0.013544119151353836
# 163
# -0.032337960100889206
# 164
# -0.0012048803310394304
# 165
# -0.030657960100889205
# 166
# -0.04126336260318756
# 167
# -0.045228160912513735
# 168
# -0.019644358990669252
# 169
# -0.005493478854179383
# 170
# -0.006570478854179381
# 171
# 0.05028628003895283
# 172
# 0.028246719283580773
# 173
# -0.03462171792936325
# 174
# -0.01119347989678383
# 175
# 0.036927478462219235
# 176
# -0.0049264788541793815
# 177
# 0.07345428207063676
# 178
# -0.007336478854179384
# 179
# 0.09411412296319008
# 180
# 0.019142439816474913
# 181
# 0.0461912425160408
# 182
# 0.06656251797962189
# 183
# 0.0522282425160408
# 184
# 0.044657478462219236
# 185
# -0.027777920500040056
# 186
# 0.0708782385621071
# 187
# 0.06291556112146378
# 188
# 0.06500224251604081
# 189
# 0.07321971928358079
# 190
# 0.06166656112146378
# 191
# 0.06449643981647492
# 192
# 0.06490224251604079
# 193
# -0.004955478854179383
# 194
# 0.0475382425160408
# 195
# 0.05351387741303444
# 196
# 0.03819987741303443
# 197
# 0.03469547846221924
# 198
# 0.06439171928358078
# 199
# -0.02599071792936325
# 200
# 0.053668320411443704
# 201
# 0.08132052114582061
# 202
# -0.0302996780359745
# 203
# 0.05961164100933075
# 204
# 0.043259637396812434
# 205
# 0.038111637396812434
# 206
# 0.07735504079139233
# 207
# 0.0003565187239646904
# 208
# -0.0033014812760353077
# 209
# 0.00014351872396469248
# 210
# -0.0005504812760353077
# 211
# -0.00239148127603531
# 212
# -0.0002854812760353098
# 213
# -0.0012714812760353071
# 214
# -0.0026414812760353103
# 215
# 0.05093603989911079
# 216
# 0.013628237796068192
# 217
# 0.07953023779606819
# 218
# -0.0010708803310394283
# 219
# 0.06653223779606819
# 220
# 0.0823432377960682
# 221
# -0.007366481276035309
# 222
# -0.008930481276035308
# 223
# -0.013859478854179381
# 224
# -0.009487719961047173
# 225
# -0.002143719961047171
# 226
# -0.006123478854179382
# 227
# 0.043523521145820615
# 228
# -0.0355756780359745
# 229
# -0.010600478854179382
# 230
# -0.02236535899066925
# 231
# -0.04253016091251373
# 232
# 0.01900764100933075
# 233
# -0.05061616091251373
# 234
# -0.016477278050661088
# 235
# 0.00870171928358078
# 236
# -0.006493278050661088
# 237
# -0.006609840070605278
# 238
# -0.046575122539043425
# 239
# 0.0006828794208765046
# 240
# 0.0007878794208765021
# 241
# -0.012358920500040053
# 242
# -0.04332343887853622
# 243
# -0.019057920500040054
# 244
# -0.0025871205791234975
# 245
# -0.0060165197143554686
# 246
# 0.033152480285644534
# 247
# 0.01357027874827385
# 248
# 0.017293281902790072
# 249
# -0.005255438878536224
# 250
# 0.0004892425160408012
# 251
# 0.0006092425160408033
# 252
# 0.015506242516040797
# 253
# -0.007125924685001367
# 254
# -0.00576492468500138
# 255
# -0.03273148202037811
# 256
# -0.012670278050661087
# 257
# -0.006687521537780766
# 258
# 0.026069877917289735
# 259
# 0.0019434784622192336
# 260
# -0.03293648202037811
# 261
# 0.0004502800389528279
# 262
# -0.030177482020378114
# 263
# 0.006950877917289731
# 264
# -0.01798092468500137
# 265
# -0.05821252153778076
# 266
# -0.0008617574839591968
# 267
# -0.012059278050661086
# 268
# -0.048136521537780766
# 269
# -0.012687278050661086
# 270
# -0.03215067958855629
# 271
# -0.005843479787945749
# 272
# 0.0001475202120542543
# 273
# -0.03449167958855629
# 274
# -0.043076160912513733
# 275
# -0.04026336260318756
# 276
# -0.01899195858836174
# 277
# -0.012556119151353837
# 278
# -0.004344720689058303
# 279
# -0.008765119151353837
# 280
# -0.044854160912513735
# 281
# -0.017083957100868224
# 282
# -0.02379412216758728
# 283
# -0.05682092468500137
# 284
# -0.029677482020378114
# 285
# -0.03190067958855629
# 286
# -0.02813667958855629
# 287
# -0.006069479880809785
# 288
# -0.005331479880809783
# 289
# -0.009579479880809785
# 290
# -0.0319516780359745
# 291
# -0.004895478854179382
# 292
# -0.03543967958855629
# 293
# -0.003410719961047172
# 294
# -0.01728047989678383
# 295
# -0.01709347989678383
# 296
# -0.02325628071641922
# 297
# -0.02678628071641922
# 298
# -0.017841122167587282
# 299
# -0.02336147989678383
# 300
# -0.04120756018352509
# 301
# -0.00904071809720993
# 302
# -0.017584920500040055
# 303
# -0.044985438878536226
# 304
# -0.0326977574839592
# 305
# -0.01974812216758728
# 306
# -0.01940812216758728
# 307
# 0.02246987791728973
# 308
# -0.0016337574839591987
# 309
# -0.014491924685001371
# 310
# -0.011035479896783829
# 311
# -0.01209292468500138
# 312
# -0.008162521537780756
# 313
# -0.009888924685001368
# 314
# 0.009013877413034443
# 315
# -0.01961612216758728
# 316
# -0.03300888297367096
# 317
# -0.01612112216758728
# 318
# -0.03736412258696556
# 319
# 0.02899087783241272
# 320
# 0.04406772194933892
# 321
# -0.029386482020378114
# 322
# 0.01096351797962189
# 323
# -0.042200319811820985
# 324
# 0.008460517979621884
# 325
# 0.01250351797962189
# 326
# -0.006911521537780768
# 327
# 0.01349287791728973
# 328
# -0.00695852153778076
# 329
# 0.016037517979621885
# 330
# -0.02308571792936325
# 331
# 0.031110641009330753
# 332
# 0.03943804079139232
# 333
# 0.02964823779606819
# 334
# -0.0011594812760353096
# 335
# -0.028026960100889207
# 336
# 0.03780823779606819
# 337
# 0.029325320134401325
# 338
# 0.01716103989911079
# 339
# 0.00197311966896057
# 340
# 0.04977127931094169
# 341
# 0.035982042899131775
# 342
# 0.011206637396812436
# 343
# 0.04005788084864616
# 344
# 0.04681604079139233
# 345
# 0.011038637396812434
# 346
# -0.0005277206890583024
# 347
# -0.013691119151353837
# 348
# -0.042481362603187564
# 349
# -0.041966160912513734
# 350
# 0.029215282070636756
# 351
# 0.03280812296319008
# 352
# 0.04734552021205425
# 353
# 0.005119280038952827
# 354
# -0.03737667958855629
# 355
# 0.011960680188179015
# 356
# 0.03327252010321617
# 357
# 0.027617122963190077
# 358
# 0.011771320411443714
# 359
# 0.019129282070636744
# 360
# 0.002527320411443712
# 361
# 0.021322122963190082
# 362
# 0.031350520103216165
# 363
# -0.02293535899066925
# 364
# -0.0322266780359745
# 365
# -0.0056534788541793835
# 366
# 0.039486280038952826
# 367
# 0.008716877917289735
# 368
# -0.019239924685001374
# 369
# 0.018473877832412722
# 370
# 0.03079587783241272
# 371
# 0.01140751797962189
# 372
# 0.016383517979621884
# 373
# 0.03293952010321617
# 374
# 0.002165680188179017
# 375
# 0.035233520103216176
# 376
# 0.015349117026329046
# 377
# 0.03486652010321617
# 378
# -0.012567479896783827
# 379
# -0.023716122082710265
# 380
# -0.0017695215377807605
# 381
# -0.005835521537780761
# 382
# -0.00522247989678383
# 383
# -0.01180747989678383
# 384
# -0.02883567958855629
# 385
# 0.010802117026329036
# 386
# 0.012164517979621883
# 387
# 0.02894787783241272
# 388
# -0.030943717929363252
# 389
# 0.03100952010321617
# 390
# 0.013678320411443706
# 391
# 0.016826321964025504
# 392
# 0.002829839087486269
# 393
# 0.0010215187239646928
# 394
# 0.0017015187239646928
# 395
# 0.07123803989911079
# 396
# 0.08320132013440132
# 397
# 0.10395411966896057
# 398
# 0.10281711966896057
# 399
# 0.011643039899110794
# 400
# -0.002934879946470261
# 401
# 0.0009115187239646903
# 402
# 0.02162464100933075
# 403
# -0.0006664788541793816
# 404
# 0.040387521145820615
# 405
# 0.03875552114582062
# 406
# -0.013843358990669252
# 407
# 0.04194452114582062
# 408
# -0.02642167958855629
# 409
# -0.04677916091251373
# 410
# 0.02217571928358078
# 411
# 0.04082652010321618
# 412
# 0.034736520103216165
# 413
# -0.04250731981182099
# 414
# 0.03417452010321617
# 415
# 0.026552719283580786
# 416
# 0.03558952010321617
# 417
# 0.025459719283580776
# 418
# 0.014782320411443714
# 419
# 0.09143364100933074
# 420
# 0.043795279310941695
# 421
# 0.11280323779606818
# 422
# 0.0030845187239646916
# 423
# -0.0005554812760353092
# 424
# -0.0019514812760353072
# 425
# 0.1232005187239647
# 426
# 0.1205065187239647
# 427
# 0.12018051872396468
# 428
# 0.0007435187239646923
# 429
# 0.1261945187239647
# 430
# -6.94812760353089e-05
# 431
# 0.1250505187239647
# 432
# 0.1269885187239647
# 433
# 0.00238611966896057
# 434
# 0.13014011966896058
# 435
# -0.0018484812760353082
# 436
# -0.00034848127603531037
# 437
# -0.0032024812760353093
# 438
# 0.10891423779606818
# 439
# 0.119471919298172
# 440
# 0.005389637396812433
# 441
# 0.0033596373968124427
# 442
# -0.0007963626031875642
# 443
# 0.024351042899131772
# 444
# -0.0006773626031875632
# 445
# 0.023900041411638262
# 446
# 0.0004256373968124366
# 447
# 0.00040663739681243843
# 448
# 0.02470904141163826
# 449
# -0.0002773626031875587
# 450
# 0.03480404079139233
# 451
# 0.025004641009330753
# 452
# 0.035598520119190215
# 453
# 0.037792521145820615
# 454
# -0.042071362603187556
# 455
# -0.04076936260318756
# 456
# -0.007856160912513732
# 457
# -0.0018643198118209886
# 458
# 0.025082320411443704
# 459
# 0.023365320411443707
# 460
# -0.02996967958855629
# 461
# 0.015415320411443709
# 462
# 0.04365528003895283
# 463
# 0.010917320411443707
# 464
# 0.014942320411443707
# 465
# 0.012324320411443712
# 466
# 0.014388320411443709
# 467
# 0.04205952114582062
# 468
# 0.013351320411443712
# 469
# 0.011039320411443704
# 470
# 0.014802320411443706
# 471
# 0.042802280038952825
# 472
# -0.0061624788541793825
# 473
# 0.005292517979621887
# 474
# -0.010698479896783828
# 475
# 0.024243122963190075
# 476
# 0.03862352114582061
# 477
# -0.02693667958855629
# 478
# -0.04130916091251373
# 479
# nan
# 480
# nan
# 481
# nan
# 482
# nan
# 483
# nan
# 484
# nan
# 485
# nan
# 486
# nan
# 487
# nan
# 488
# nan
# 489
# nan
# 490
# nan
# 491
# nan
# 492
# nan
# 493
# nan
# 494
# nan
# 495
# nan
# 496
# nan
# 497
# nan
# 498
# nan
# 499
# !!!!!!!The sensor is not working properly!!!!!!!!
# nan
# 500
# !!!!!!!The sensor is not working properly!!!!!!!!
# nan
# 501
# !!!!!!!The sensor is not working properly!!!!!!!!
# nan
# 502
# !!!!!!!The sensor is not working properly!!!!!!!!
# nan
# 503
# !!!!!!!The sensor is not working properly!!!!!!!!
# nan
# 504
# !!!!!!!The sensor is not working properly!!!!!!!!
# nan
# 505
# !!!!!!!The sensor is not working properly!!!!!!!!
# nan
# 506
# !!!!!!!The sensor is not working properly!!!!!!!!
# nan
# 507
# !!!!!!!The sensor is not working properly!!!!!!!!
# nan
# 508
# !!!!!!!The sensor is not working properly!!!!!!!!
# nan
# 509
# !!!!!!!The sensor is not working properly!!!!!!!!
# nan
# 510
# !!!!!!!The sensor is not working properly!!!!!!!!
# nan
# 511
# !!!!!!!The sensor is not working properly!!!!!!!!
# nan
# 512
# !!!!!!!The sensor is not working properly!!!!!!!!
# nan
# 513
# !!!!!!!The sensor is not working properly!!!!!!!!
# nan
# 514
# !!!!!!!The sensor is not working properly!!!!!!!!
# nan
# 515
# !!!!!!!The sensor is not working properly!!!!!!!!
# nan
# 516
# -7.236260318756182e-05
# 517
# -0.0003073626031875609
# 518
# 0.002825637396812436
# 519
# -0.04028736260318756
# 520
# !!!!!!!The sensor is not working properly!!!!!!!!
# nan
# 521
# -0.015062119151353835
# 522
# -0.025526119151353836
# 523
# -0.032429957100868226
# 524
# -0.019379478854179382
# 525
# -0.02908647989678383
# 526
# -0.043890122082710266
# 527
# -0.056776757483959196
# 528
# -0.056377438878536225
# 529
# -0.027965920500040056
# 530
# -0.02874571809720993
# 531
# -0.02845272125172615
# 532
# -0.012749120579123497
# 533
# -0.012575120579123498
# 534
# -0.01316751971435547
# 535
# -0.018111119552135468
# 536
# -0.017981119552135466
# 537
# -0.017856119552135466
# 538
# -0.01413624041736126
# 539
# -0.006793840070605278
# 540
# -0.006745840070605278
# 541
# -0.006670840070605278
# 542
# -0.006636840070605278
# 543
# -0.006696840070605278
# 544
# -0.006582840070605278
# 545
# -0.006674840070605278
# 546
# -0.006738840070605278
# 547
# -0.0001148400706052783
# 548
# -0.006701840070605278
# 549
# -0.0010508400706052776
# 550
# -0.0024868400706052774
# 551
# -0.0028668400706052775
# 552
# -0.006572840070605278
# 553
# 0.0003921599293947222
# 554
# -0.006505840070605278
# 555
# -0.006632840070605278
# 556
# -0.0066638400706052784
# 557
# -0.006714840070605278
# 558
# -0.006610840070605278
# 559
# -0.006576840070605278
# 560
# 0.0014381599293947223
# 561
# -7.084007060527767e-05
# 562
# -0.006265840070605278
# 563
# 0.005355159929394723
# 564
# -0.004717119552135468
# 565
# -0.01540447989678383
# 566
# -0.053092319811820984
# 567
# -0.02856571792936325
# 568
# -0.02887567958855629
# 569
# -0.005579478854179382
# 570
# -0.026593678035974504
# 571
# -0.01738835899066925
# 572
# -0.01759935899066925
# 573
# -0.040207362603187566
# 574
# 0.004340637396812438
# 575
# -0.015748358990669252
# 576
# -0.0036944798808097833
# 577
# 0.0003885211458206188
# 578
# -0.03056367958855629
# 579
# 0.03837352011919022
# 580
# 0.017169320411443714
# 581
# -0.02593567958855629
# 582
# -0.0035824788541793835
# 583
# -0.02987867958855629
# 584
# -0.02939167958855629
# 585
# -0.03172167958855629
# 586
# -0.0030554797879457467
# 587
# 0.02993052021205425
# 588
# -0.03491967958855629
# 589
# -0.02135887703680992
# 590
# -0.011277479896783828
# 591
# -0.01788287703680992
# 592
# -0.02045312216758728
# 593
# -0.04115212253904343
# 594
# -0.003538120579123496
# 595
# -0.005361519714355469
# 596
# 0.0010344802856445297
# 597
# -0.009245721251726152
# 598
# -0.014530920500040054
# 599
# 0.021373079499959945
# 600
# -0.04146343887853622
# 601
# 0.01986528190279007
# 602
# -0.012001920500040054
# 603
# -0.0416317574839592
# 604
# -0.042976757483959196
# 605
# -0.05467292468500137
# 606
# -0.025517122082710265
# 607
# -0.01392452153778076
# 608
# -0.029436122082710268
# 609
# -0.048564521537780764
# 610
# -0.03316648202037811
# 611
# -0.02099928071641922
# 612
# -0.04568631981182099
# 613
# -0.02282028071641922
# 614
# -0.03442748202037811
# 615
# -0.02604028071641922
# 616
# -0.01892112216758728
# 617
# -0.037574560183525084
# 618
# 0.006046877460956571
# 619
# -0.0028155601835250857
# 620
# -0.03525348202037811
# 621
# -0.03337567958855629
# 622
# -0.004188478854179382
# 623
# 0.042609280038952826
# 624
# 0.01565387791728974
# 625
# -0.052967924685001375
# 626
# 0.00010524251604079882
# 627
# -0.033634122082710265
# 628
# -0.013363479896783829
# 629
# 0.01951051797962189
# 630
# -0.01715612216758728
# 631
# -0.04301475748395919
# 632
# -0.0008457614378929168
# 633
# -0.029906924685001376
# 634
# 0.013450721949338912
# 635
# 0.032317520103216174
# 636
# 0.07772152010321617
# 637
# -0.0023937199610471714
# 638
# -0.008847479787945749
# 639
# -0.04215836260318756
# 640
# -0.005740478854179384
# 641
# 0.029646680188179023
# 642
# 0.06206871928358078
# 643
# 0.027535517979621893
# 644
# 0.05279851797962189
# 645
# 0.05093351797962188
# 646
# 0.038553520103216166
# 647
# 0.05929371928358078
# 648
# 0.041389877832412714
# 649
# 0.04024187783241272
# 650
# 0.027055517979621885
# 651
# 0.09840451797962188
# 652
# 0.04454472194933891
# 653
# -0.045752319811820985
# 654
# -0.02423528071641922
# 655
# -0.02336628071641922
# 656
# -0.034936482020378114
# 657
# -0.053237924685001374
# 658
# -0.05692792468500137
# 659
# -0.03858012258696556
# 660
# -0.03803776143789291
# 661
# -0.0033845601835250858
# 662
# -0.0412877574839592
# 663
# -0.03579676143789291
# 664
# -0.05552392468500138
# 665
# -0.029076122082710265
# 666
# -0.03633776143789291
# 667
# -0.0394617574839592
# 668
# -0.015246438878536224
# 669
# 0.03003007949995995
# 670
# 0.020925079499959948
# 671
# 0.025508079499959944
# 672
# -0.010832920500040054
# 673
# -0.03826012253904343
# 674
# -0.011098920500040053
# 675
# 0.04247707949995995
# 676
# 0.034495079499959946
# 677
# -0.03862756018352509
# 678
# -0.03895356018352508
# 679
# 0.040942281902790076
# 680
# 0.01823328190279007
# 681
# -0.011719920500040053
# 682
# -0.03131312253904343
# 683
# -0.002759560183525085
# 684
# -0.03953812253904343
# 685
# -0.02408571809720993
# 686
# -0.007264120579123496
# 687
# -0.0009135197143554687
# 688
# 0.0316858794208765
# 689
# -0.013986920500040054
# 690
# -0.010238560183525085
# 691
# -0.0420917574839592
# 692
# -0.03884276143789291
# 693
# -0.006137924685001378
# 694
# -0.009273924685001378
# 695
# 0.03464072194933891
# 696
# 0.02576971928358078
# 697
# 0.02647671928358078
# 698
# 0.031480282070636745
# 699
# -0.003949478854179383
# 700
# -0.027096678035974504
# 701
# 0.028476320411443712
# 702
# -0.04424367958855629
# 703
# -0.06450892468500137
# 704
# -0.027893920500040054
# 705
# -0.01759571809720993
# 706
# 0.024738281902790073
# 707
# -0.03701156018352508
# 708
# -0.027942122082710266
# 709
# -0.01622028071641922
# 710
# 0.03386272194933891
# 711
# -0.015266877036809921
# 712
# -0.03032667958855629
# 713
# 0.04242452114582061
# 714
# -0.0008314788541793836
# 715
# -0.003295478854179381
# 716
# -0.0013134788541793833
# 717
# -0.031168679588556288
# 718
# -0.02883167958855629
# 719
# -0.004442479787945746
# 720
# 0.01806528207063675
# 721
# 0.03137572194933891
# 722
# -0.048884521537780765
# 723
# -0.03946452153778076
# 724
# 0.019021877917289737
# 725
# 0.015232517979621885
# 726
# -0.03170948202037811
# 727
# -0.009618278050661087
# 728
# -0.03104848202037811
# 729
# 0.012690517979621882
# 730
# 0.012295320411443711
# 731
# -0.02944167958855629
# 732
# 0.017951719283580782
# 733
# -0.0067255215377807626
# 734
# -0.007650521537780758
# 735
# -0.051558924685001374
# 736
# -0.012527278050661086
# 737
# -0.014981278050661087
# 738
# -0.02682428071641922
# 739
# -0.03655048202037811
# 740
# -0.01954292468500137
# 741
# -0.06124292468500137
# 742
# -0.03720556018352508
# 743
# 0.025850079499959946
# 744
# -0.0042844388785362245
# 745
# -0.0011325601835250887
# 746
# -0.004435438878536223
# 747
# 0.008555439816474913
# 748
# 0.008333439816474913
# 749
# 0.009085439816474916
# 750
# 0.0026144398164749116
# 751
# 0.00887143981647491
# 752
# 0.012079439816474913
# 753
# -0.0419127574839592
# 754
# -0.01020992468500137
# 755
# 0.007966439816474921
# 756
# -0.01569212216758728
# 757
# -0.027714920500040055
# 758
# -0.013220519714355469
# 759
# -0.01420424041736126
# 760
# -0.006599840070605278
# 761
# -0.006698840070605278
# 762
# -0.006569840070605278
# 763
# 0.00019415992939472194
# 764
# -0.006535840070605278
# 765
# -0.006425840070605278
# 766
# -0.006718840070605278
# 767
# -0.006682840070605278
# 768
# -0.006611840070605278
# 769
# -0.006611840070605278
# 770
# -0.006648840070605278
# 771
# -0.006802840070605278
# 772
# 0.0008551599293947221
# 773
# 0.0010421599293947217
# 774
# 0.0008621599293947221
# 775
# 0.001318159929394722
# 776
# -0.006670840070605278
# 777
# -0.006668840070605278
# 778
# -0.006734840070605278
# 779
# 0.0008441599293947215
# 780
# 0.0011351599293947228
# 781
# -0.006740840070605278
# 782
# -0.006685840070605278
# 783
# -0.006694840070605278
# 784
# -0.006675840070605278
# 785
# 0.002683159929394722
# 786
# 0.002966159929394722
# 787
# 0.0033991599293947215
# 788
# -0.0021808400706052784
# 789
# -0.002145840070605278
# 790
# -0.0022668400706052777
# 791
# -0.002008840070605278
# 792
# -0.0024808400706052783
# 793
# -0.002399840070605279
# 794
# -0.002628840070605277
# 795
# -0.0025268400706052775
# 796
# -0.0020428400706052775
# 797
# -0.002131840070605278
# 798
# -0.0024748400706052776
# 799
# -0.0020568400706052776
# 800
# -0.0019678400706052788
# 801
# -0.002615840070605278
# 802
# -0.004053840070605278
# 803
# 0.0025921599293947228
# 804
# -0.0010382404173612594
# 805
# 0.0032434802856445323
# 806
# -0.01215571809720993
# 807
# 0.03742507949995995
# 808
# -0.03748856018352509
# 809
# -0.03698376143789291
# 810
# -0.0432217574839592
# 811
# -0.0442737574839592
# 812
# -0.0437307574839592
# 813
# -0.045222757483959194
# 814
# 0.004125561121463769
# 815
# -0.03859356018352508
# 816
# 0.006473439816474913
# 817
# 0.006309075314998622
# 818
# 0.02678287791728974
# 819
# -0.028886122082710266
# 820
# 0.030013520103216174
# 821
# 0.01106387741303444
# 822
# 0.033089877832412726
# 823
# -0.0036855215377807615
# 824
# -0.03339688297367096
# 825
# 0.031496877832412715
# 826
# 0.03791172194933891
# 827
# 0.03820372194933891
# 828
# 0.03362952010321617
# 829
# 0.020063877917289738
# 830
# -0.028984122082710267
# 831
# 0.03613872194933891
# 832
# 0.018481877917289738
# 833
# -0.05037252153778076
# 834
# -0.013508479787945747
# 835
# -0.0496727574839592
# 836
# 0.0003865611214637771
# 837
# -0.031606482020378114
# 838
# 0.020687719283580777
# 839
# 0.038569521145820615
# 840
# 0.041317521145820615
# 841
# -0.02000367986559868
# 842
# -0.002352481276035309
# 843
# -0.0026554812760353104
# 844
# 0.040293518723964694
# 845
# 0.028791041411638255
# 846
# 0.025783042899131775
# 847
# 0.03387988084864617
# 848
# 0.039594040791392324
# 849
# 0.054832919298171995
# 850
# 0.10884012005352975
# 851
# 0.09398623779606818
# 852
# 0.10800012005352974
# 853
# -0.006919720689058304
# 854
# -0.01818795858836174
# 855
# 0.028091041411638262
# 856
# 0.03832804079139232
# 857
# 0.028568041411638254
# 858
# -0.031684960100889205
# 859
# -0.00262748127603531
# 860
# -0.00043248127603530764
# 861
# -0.039373362603187564
# 862
# 0.037772521145820616
# 863
# -0.02684667958855629
# 864
# 0.012046320411443712
# 865
# 0.012312320411443714
# 866
# 0.012022320411443715
# 867
# 0.013273320411443704
# 868
# 0.00979732041144371
# 869
# 0.011729320411443714
# 870
# -0.03004767958855629
# 871
# -0.02420435899066925
# 872
# -0.0001137199610471741
# 873
# 0.017960282070636754
# 874
# 0.04618628003895282
# 875
# -0.02123835899066925
# 876
# -0.02285935899066925
# 877
# -0.004866478854179384
# 878
# 0.03941428003895283
# 879
# 0.012048877917289737
# 880
# 0.026587877832412718
# 881
# -0.008740521537780759
# 882
# 0.023776877832412717
# 883
# 0.005439238562107089
# 884
# -0.004591924685001372
# 885
# -0.032105482020378114
# 886
# 0.018019877917289734
# 887
# 0.01608587791728973
# 888
# 0.019256877917289736
# 889
# 0.027891877832412718
# 890
# 0.02396587783241272
# 891
# 0.01697387791728973
# 892
# 0.025712877832412717
# 893
# 0.016571117026329046
# 894
# 0.03054487783241272
# 895
# -0.04934452153778077
# 896
# 0.014505719283580777
# 897
# -0.0021211225869655626
# 898
# -0.01347092468500137
# 899
# -0.01236992468500138
# 900
# 0.005010238562107083
# 901
# -0.014522924685001375
# 902
# -0.013805924685001372
# 903
# 0.0017384398164749168
# 904
# 0.0007382425160408074
# 905
# 0.015543877917289728
# 906
# 0.02970552010321617
# 907
# 0.008690517979621885
# 908
# -0.03328848202037811
# 909
# -0.04404716091251373
# 910
# -0.019748957100868225
# 911
# -0.001280122586965561
# 912
# 0.007792439816474914
# 913
# -0.03404043887853622
# 914
# 0.0012782425160408062
# 915
# -0.037381438878536226
# 916
# 0.01121787746095658
# 917
# -0.026127122539043427
# 918
# -0.0457467574839592
# 919
# 0.030289079499959945
# 920
# 0.006418561121463773
# 921
# -0.06401192468500137
# 922
# -0.04009656018352509
# 923
# 0.005890561121463772
# 924
# 0.00649443981647492
# 925
# 0.009015439816474916
# 926
# 0.006383242516040805
# 927
# -0.01871912216758728
# 928
# -0.02775628071641922
# 929
# -0.02122912216758728
# 930
# -0.04751452153778076
# 931
# -0.0018434388785362257
# 932
# -0.005593438878536222
# 933
# 0.031053079499959946
# 934
# 0.007582877460956573
# 935
# 0.0035615611214637743
# 936
# 0.0066374398164749104
# 937
# 0.0048155611214637795
# 938
# 0.0057564398164749175
# 939
# 0.0052725611214637785
# 940
# 0.005601439816474915
# 941
# 0.01067043981647492
# 942
# 0.004620561121463779
# 943
# 0.004587439816474914
# 944
# -0.038149761437892914
# 945
# -0.05922292468500137
# 946
# -0.046083757483959195
# 947
# -0.0459897574839592
# 948
# -0.005174560183525086
# 949
# -0.03893956018352508
# 950
# 0.02601207949995995
# 951
# 0.025855281902790073
# 952
# 0.02588028190279007
# 953
# 0.10209207949995994
# 954
# 0.03299707949995995
# 955
# 0.03444807949995994
# 956
# 0.03637407949995995
# 957
# -0.036908560183525084
# 958
# -0.05449992468500137
# 959
# -0.038559438878536224
# 960
# -0.0385037574839592
# 961
# -0.05003492468500137
# 962
# -0.0382627574839592
# 963
# 0.004428439816474908
# 964
# -0.027720920500040054
# 965
# -0.027916920500040056
# 966
# -0.02833472125172615
# 967
# -0.01307751971435547
# 968
# -0.017746119552135467
# 969
# -0.01419324041736126
# 970
# -0.006794840070605278
# 971
# -0.006824840070605278
# 972
# -0.006609840070605278
# 973
# -0.006594840070605278
# 974
# -0.006712840070605278
# 975
# -0.006780840070605278
# 976
# -0.006631840070605278
# 977
# -0.006656840070605278
# 978
# -0.006613840070605278
# 979
# -0.006530840070605278
# 980
# -0.006774840070605278
# 981
# -0.006670840070605278
# 982
# -0.006850840070605278
# 983
# -0.006627840070605278
# 984
# -0.006768840070605278
# 985
# -0.006765840070605278
# 986
# -0.006697840070605278
# 987
# -0.006605840070605278
# 988
# -0.006587840070605278
# 989
# -0.006637840070605278
# 990
# -0.006674840070605278
# 991
# -0.006642840070605278
# 992
# -0.006746840070605278
# 993
# -0.006671840070605278
# 994
# -0.006503840070605278
# 995
# -0.006610840070605278
# 996
# -0.006794840070605278
# 997
# -0.006602840070605278
# 998
# -0.006672840070605278
# 999
# -0.006722840070605278
# 1000
# -0.006869840070605278
# 1001
# -0.006583840070605278
# 1002
# -0.006633840070605278
# 1003
# -0.006878840070605278
# 1004
# -0.006889840070605278
# 1005
# -0.006716840070605278
# 1006
# -0.006670840070605278
# 1007
# -0.006682840070605278
# 1008
# -0.006629840070605278
# 1009
# -0.006804840070605278
# 1010
# -0.006801840070605278
# 1011
# -0.006684840070605278
# 1012
# -0.0066508400706052784
# 1013
# -0.006798840070605278
# 1014
# -0.006581840070605278
# 1015
# -0.006597840070605278
# 1016
# -0.006782840070605278
# 1017
# -0.006787840070605278
# 1018
# -0.006535840070605278
# 1019
# -0.006753840070605278
# 1020
# -0.006698840070605278
# 1021
# -0.006762840070605278
# 1022
# -0.006686840070605278
# 1023
# -0.006647840070605278
# 1024
# -0.006557840070605278
# 1025
# -0.006537840070605278
# 1026
# -0.006694840070605278
# 1027
# -0.006641840070605278
# 1028
# -0.006553840070605278
# 1029
# -0.006515840070605278
# 1030
# -0.005777840070605278
# 1031
# -0.006518840070605278
# 1032
# -0.002825840070605278
# 1033
# -0.0036388400706052777
# 1034
# -0.0034158400706052784
# 1035
# -0.003576840070605278
# 1036
# 0.007652159929394723
# 1037
# 0.004492159929394723
# 1038
# -0.0015751205791234985
# 1039
# -0.011575920500040054
# 1040
# -0.042606560183525086
# 1041
# -0.0384437574839592
# 1042
# -0.016281920500040053
# 1043
# -0.008908920500040055
# 1044
# -0.012390920500040054
# 1045
# -0.038027560183525086
# 1046
# 0.007824877413034434
# 1047
# 0.034545877832412725
# 1048
# 0.02599071928358078
# 1049
# 0.016010320411443707
# 1050
# 0.019768321964025504
# 1051
# 0.04601852011919022
# 1052
# 0.03441364100933075
# 1053
# 0.010370637396812432
# 1054
# -0.03884236260318756
# 1055
# -0.003938160912513734
# 1056
# 0.034314520119190214
# 1057
# 0.019691641009330747
# 1058
# 0.04206452114582061
# 1059
# 0.03766652114582062
# 1060
# -0.03635736260318756
# 1061
# 0.011080320411443717
# 1062
# 0.01024032041144371
# 1063
# 0.03633752114582062
# 1064
# -0.03011067958855629
# 1065
# 0.03960128003895283
# 1066
# 0.026800520103216173
# 1067
# 0.029903520103216175
# 1068
# -0.01682687703680992
# 1069
# 0.02261912296319008
# 1070
# -0.01675887703680992
# 1071
# 0.020326719283580777
# 1072
# 0.009535320411443712
# 1073
# 0.023066719283580783
# 1074
# -0.043915679588556286
# 1075
# -0.02091687703680992
# 1076
# -0.02535571792936325
# 1077
# -0.02225387703680992
# 1078
# 0.007816517979621886
# 1079
# -0.03009588297367096
# 1080
# -0.02040828071641922
# 1081
# -0.008226521537780765
# 1082
# -0.030837482020378112
# 1083
# -0.011229924685001377
# 1084
# -0.009097924685001368
# 1085
# -0.023734122082710266
# 1086
# 0.016327877917289735
# 1087
# -0.046790521537780766
# 1088
# 0.015023877917289735
# 1089
# -0.0020265215377807677
# 1090
# 0.02779887783241272
# 1091
# 0.01194851797962189
# 1092
# -0.005763521537780758
# 1093
# -0.005686521537780764
# 1094
# 0.028923877832412723
# 1095
# -0.008246278050661086
# 1096
# -0.008269719961047172
# 1097
# 0.02195371928358078
# 1098
# 0.022319719283580786
# 1099
# 0.018529719283580777
# 1100
# -0.02149228071641922
# 1101
# -0.001899319811820982
# 1102
# 0.012754320411443712
# 1103
# 0.024338122963190073
# 1104
# 0.014114320411443712
# 1105
# 0.010387320411443711
# 1106
# 0.04354052114582062
# 1107
# 0.0135063219640255
# 1108
# 0.013829321964025504
# 1109
# 0.01887564100933075
# 1110
# -0.007395119151353838
# 1111
# -0.00020972068905830352
# 1112
# -0.003206879946470259
# 1113
# -0.030346482020378113
# 1114
# 0.02506152010321617
# 1115
# 0.015585719283580782
# 1116
# 0.01806771928358078
# 1117
# 0.01978112296319008
# 1118
# 0.035725521145820616
# 1119
# -0.01465035899066925
# 1120
# -0.041595362603187566
# 1121
# -0.0015823626031875593
# 1122
# -0.0037581609125137347
# 1123
# 0.026084442135334014
# 1124
# 0.032031641009330744
# 1125
# 0.014496321964025491
# 1126
# -0.04283636260318756
# 1127
# 0.03874752114582061
# 1128
# -0.028765678035974504
# 1129
# 0.008099320411443713
# 1130
# -0.02219767958855629
# 1131
# 0.011227320411443711
# 1132
# -0.04149167958855629
# 1133
# -0.00934747989678383
# 1134
# 0.02144387791728973
# 1135
# -0.006827521537780767
# 1136
# 0.09230787783241273
# 1137
# 0.0950018778324127
# 1138
# 0.004166877413034439
# 1139
# 0.028021877832412723
# 1140
# 0.0794115179796219
# 1141
# 0.08777471928358077
# 1142
# -0.01623612216758728

# %%
plt.figure(figsize=(12, 6))
ax = plt.axes()
ax.set_facecolor("white")
ax.spines['bottom'].set_color('black')
ax.spines['top'].set_color('black') 
ax.spines['right'].set_color('black')
ax.spines['left'].set_color('black')
plt.plot(X_validation["time"], resi_plot, label = "Residue",linestyle='-') 
plt.legend() 
plt.show()

# %% [markdown]
# ## PCA testing

# %%
DF_Q4.columns
# Out:
# Index(['sensorId', 'accelRMS.x', 'accelRMS.y', 'accelRMS.z', 'duration',
#        'sampRate', 'timeStart', 'velRMS.x', 'velRMS.y', 'velRMS.z', 'temp',
#        'time'],
#       dtype='object')

# %%
DF_Q4_PCA = DF_Q4[['accelRMS.x', 'accelRMS.y', 'accelRMS.z',
       'velRMS.x', 'velRMS.y', 'velRMS.z', 'temp',
       'time']].copy()
scar = StandardScaler()
DF_Q4_PCA_scar = scar.fit_transform(DF_Q4_PCA)
DF_Q4_PCA_scar = pd.DataFrame(DF_Q4_PCA_scar)
DF_Q4_PCA_scar.rename(index=str,columns={0:'accelRMS.x'
                                         ,1: 'accelRMS.y'
                                         ,2: 'accelRMS.z'
                                         ,3: 'velRMS.x'
                                         ,4: 'velRMS.y'
                                         ,5: 'velRMS.z'
                                         ,6: 'temp'
                                         ,7: 'time'},inplace=True)
pca_test_2 = PCA(n_components=2)
DF_Q4_PCA_scar.fillna(0,inplace=True)
output_2 = pca_test_2.fit_transform(DF_Q4_PCA_scar)
pca_test_2.explained_variance_ratio_
pca_test_2.explained_variance_ratio_.sum() # "interpretability" of 86%
# Out:
# 0.8613808545128803

# %%
plt.figure(figsize=(12, 6))
ax = plt.axes()
ax.set_facecolor("white")
ax.spines['bottom'].set_color('black')
ax.spines['top'].set_color('black') 
ax.spines['right'].set_color('black')
ax.spines['left'].set_color('black')
square1 = patches.Rectangle((-3.25, -2), 2.5, 4.5, edgecolor='orange', facecolor='none')
ax.add_patch(square1)
square2 = patches.Rectangle((0, -2), 2, 2, edgecolor='green', facecolor='none')
ax.add_patch(square2)
square3 = patches.Rectangle((0.45, 0.3), 1.5, 1.5, edgecolor='yellow', facecolor='none')
ax.add_patch(square3)
square4 = patches.Rectangle((3, 0.3), 1.6, 1.5, edgecolor='purple', facecolor='none')
ax.add_patch(square4)

square5 = patches.Rectangle((3.2, -0.9), 1.6, 1, edgecolor='red', facecolor='none')
ax.add_patch(square5)
plt.scatter(x=output_2[:,0],y=output_2[:,1])
plt.legend() 
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# 5 distinct operational points.
